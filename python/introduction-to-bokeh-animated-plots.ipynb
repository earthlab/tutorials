# %% [markdown]
# ---
# layout: single
# title: 'Introduction to Bokeh in Python'
# date: 2016-08-01
# authors: [Matt Oakley]
# category: [tutorials]
# excerpt: 'This tutorial outlines some basic interactive plotting functionality in Bokeh.'
# sidebar:
#   nav:
# author_profile: false
# comments: true
# lang: [python]
# lib: [bokeh, csv]
# ---
#
# Another powerful visualization library available for Python is Bokeh. Much like other libraries such as Matplotlib, the aim of Bokeh is to be able to quickly and easily create interactive plots from data. This tutorial will go over the basic functionality of Bokeh.
#
# Note: this tutorial produces interactive plots. If not running locally, we recommend using [nbviewer](http://nbviewer.jupyter.org/github/earthlab/tutorials/blob/master/python/introduction_to_bokeh.ipynb) to view the tutorial.
#
# ## Objectives
#
# - Create a simple plot using Bokeh
# - Create a geospatial plot of points on a map using Bokeh
#
# ## Dependencies
#
# - Bokeh

# %%
from bokeh.io import output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.plotting import figure
import csv

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d399410-52f1-45be-abcd-db738ad15a7b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Creating a Simple Plot
#
# Let's first create a simple plot of points on a Cartesian plane using Bokeh. We'll also try and change the look of our plot with Bokeh's customization features for different glyphs, markers, etc.

# %%
#Define our points to display
x_points = [1, 2, 3, 4, 5, 6, 7]
y_points = [6, 5, 4, 3, 4, 5, 6]

#Create the plot
square_plot = figure(plot_width = 400, plot_height = 400)
square_plot.square(x_points, y_points, fill_color = "red", size = 8)

#Show the plot
show(square_plot)
# Out:
#     <div class="plotdiv" id="cc437a87-3ea8-463b-81c0-16a363b13ecc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc437a87-3ea8-463b-81c0-16a363b13ecc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc437a87-3ea8-463b-81c0-16a363b13ecc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"53dc942e-0dc2-42d1-b536-c8af90433d69":{"roots":{"references":[{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"561287dc-6175-4f4c-b224-f55b99ba7a09","type":"BasicTicker"}},"id":"2da5687a-a8a4-46d8-8da7-f88314788982","type":"Grid"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"fc890cbd-3973-4268-8fae-ed474d7c29f9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"04fce092-7d64-4f83-872f-c4698a49e469","type":"ResetTool"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"e1698bac-d1fe-4387-ae9c-8398eb56639f","type":"HelpTool"},{"attributes":{"formatter":{"id":"b25316cb-984f-47b7-abbc-2c05e5ddb6a5","type":"BasicTickFormatter"},"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"561287dc-6175-4f4c-b224-f55b99ba7a09","type":"BasicTicker"}},"id":"932445f9-0a7a-4315-b771-453fdafbe414","type":"LinearAxis"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"7fdbb679-976d-4a4a-bb9e-fcc88acb5c0b","type":"ResizeTool"},{"attributes":{},"id":"463eadc0-2e2f-46db-bd5c-fb112ea1e1f7","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"16e60113-62d9-48cd-8a58-9202d218e6c5","type":"BasicTicker"}},"id":"e096adf2-288b-4a5f-a843-cd778f0165fe","type":"Grid"},{"attributes":{"overlay":{"id":"443eecfc-5c13-4582-80da-165c1e4e83fc","type":"BoxAnnotation"},"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"342ebc8b-267a-4d78-b207-376d3e0ae8cd","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"d225e3cc-8675-4b78-8449-508ced628896","type":"DataRange1d"},{"attributes":{},"id":"561287dc-6175-4f4c-b224-f55b99ba7a09","type":"BasicTicker"},{"attributes":{"data_source":{"id":"9b6e05ad-8906-48d0-9b07-0abc7085e8f5","type":"ColumnDataSource"},"glyph":{"id":"5ddb63b2-1e40-4506-b74b-068a2f9ebbe3","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"3b215dc3-3090-41d8-9cd7-df9da3ec6b2f","type":"Square"},"selection_glyph":null},"id":"1613a268-eb15-4a83-9b1b-61d73e510bc1","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ddb63b2-1e40-4506-b74b-068a2f9ebbe3","type":"Square"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"443eecfc-5c13-4582-80da-165c1e4e83fc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"ccdbde01-a00d-4207-bc81-57836345d3a9","type":"PanTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"9b6e05ad-8906-48d0-9b07-0abc7085e8f5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b215dc3-3090-41d8-9cd7-df9da3ec6b2f","type":"Square"},{"attributes":{"callback":null},"id":"8bdfde9b-ab1a-4763-9e8d-1ee2c0c88f4b","type":"DataRange1d"},{"attributes":{},"id":"b25316cb-984f-47b7-abbc-2c05e5ddb6a5","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"463eadc0-2e2f-46db-bd5c-fb112ea1e1f7","type":"BasicTickFormatter"},"plot":{"id":"be00387f-a28f-44b6-9df3-a5597 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# As previously stated, Bokeh has a multitude of different customizations which can change the look of your plot. Let's change the squares to circles and fill them in with a different color.

# %%
#Set up a new plot using circles
circle_plot = figure(plot_width = 400, plot_height = 400)
circle_plot.circle(x_points, y_points, fill_color = "blue", size = 9)

#Display the plot
show(circle_plot)
# Out:
#     <div class="plotdiv" id="fdfbcbcf-f696-44e4-b0e8-8fbde7e86287"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fdfbcbcf-f696-44e4-b0e8-8fbde7e86287");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '
type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3bc9d15-b45d-491e-995d-0da63f7d1d2b","type":"Circle"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ddb63b2-1e40-4506-b74b-068a2f9ebbe3","type":"Square"},{"attributes":{"formatter":{"id":"463eadc0-2e2f-46db-bd5c-fb112ea1e1f7","type":"BasicTickFormatter"},"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"16e60113-62d9-48cd-8a58-9202d218e6c5","type":"BasicTicker"}},"id":"16ca9a95-c033-4324-b4b4-910038bae0cb","type":"LinearAxis"},{"attributes":{"plot":{"id":"daaf9eed-03de-4d78-a459-bc143ff22a3b","subtype":"Figure","type":"Plot"}},"id":"10fbf8dd-2ac7-4c67-9eff-4c0834f04b2b","type":"ResetTool"},{"attributes":{},"id":"16e60113-62d9-48cd-8a58-9202d218e6c5","type":"BasicTicker"},{"attributes":{"plot":{"id":"daaf9eed-03de-4d78-a459-bc143f ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# Finally, let's display a line on our plot connecting all of our plotted points.

# %%
#Create a line connecting our plotted points
circle_plot.line(x_points, y_points, line_width = 2)

#Display the plot
show(circle_plot)
# Out:
#     <div class="plotdiv" id="3bec5846-b112-4efd-bf8d-4791774b5285"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3bec5846-b112-4efd-bf8d-4791774b5285");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3bec5846-b112-4efd-bf8d-4791774b5285' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d584608-6974-424b-b0cb-687788daa258":{"roots":{"references":[{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"561287dc-6175-4f4c-b224-f55b99ba7a09","type":"BasicTicker"}},"id":"2da5687a-a8a4-46d8-8da7-f88314788982","type":"Grid"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"fc890cbd-3973-4268-8fae-ed474d7c29f9","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"579b01d5-6203-4ed1-bc61-4ef5216eb6c7","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"d1036e69-7d49-40af-8591-0e0c7c5e954c","type":"ColumnDataSource"},"glyph":{"id":"66a97b42-d2bd-471f-807c-1ef9ab80f352","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"31e6c1ae-e543-46f1-aa9b-84d583c5f94f","type":"Line"},"selection_glyph":null},"id":"90f0b201-6c79-4bd9-9b0d-77f68fb472fa","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"e1698bac-d1fe-4387-ae9c-8398eb56639f","type":"HelpTool"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"7fdbb679-976d-4a4a-bb9e-fcc88acb5c0b","type":"ResizeTool"},{"attributes":{"dimension":1,"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"16e60113-62d9-48cd-8a58-9202d218e6c5","type":"BasicTicker"}},"id":"e096adf2-288b-4a5f-a843-cd778f0165fe","type":"Grid"},{"attributes":{"plot":{"id":"daaf9eed-03de-4d78-a459-bc143ff22a3b","subtype":"Figure","type":"Plot"},"ticker":{"id":"a90c514c-e33c-420f-bb53-97dcb190cf33","type":"BasicTicker"}},"id":"b5499da3-ecf7-4684-baac-31cf4306c8f7","type":"Grid"},{"attributes":{"callback":null},"id":"d225e3cc-8675-4b78-8449-508ced628896","type":"DataRange1d"},{"attributes":{},"id":"561287dc-6175-4f4c-b224-f55b99ba7a09","type":"BasicTicker"},{"attributes":{"data_source":{"id":"9b6e05ad-8906-48d0-9b07-0abc7085e8f5","type":"ColumnDataSource"},"glyph":{"id":"5ddb63b2-1e40-4506-b74b-068a2f9ebbe3","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"3b215dc3-3090-41d8-9cd7-df9da3ec6b2f","type":"Square"},"selection_glyph":null},"id":"1613a268-eb15-4a83-9b1b-61d73e510bc1","type":"GlyphRenderer"},{"attributes":{},"id":"b25316cb-984f-47b7-abbc-2c05e5ddb6a5","type":"BasicTickFormatter"},{"attributes":{},"id":"b6a2fcf0-160d-4809-a7cd-75fc2e903c83","type":"BasicTicker"},{"attributes":{"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"}},"id":"ccdbde01-a00d-4207-bc81-57836345d3a9","type":"PanTool"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"e359ebc8-ff5b-400e-89c8-5db67722aaff","type":"Circle"},{"attributes":{},"id":"210473c4-1408-411a-8c71-93c6a599e86a","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3bc9d15-b45d-491e-995d-0da63f7d1d2b","type":"Circle"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ddb63b2-1e40-4506-b74b-068a2f9ebbe3","type":"Square"},{"attributes":{"formatter":{"id":"463eadc0-2e2f-46db-bd5c-fb112ea1e1f7","type":"BasicTickFormatter"},"plot":{"id":"be00387f-a28f-44b6-9df3-a5597743b7e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"16e60113-62d9-48cd-8a58-9202d218e6c5","type":"BasicTicker"}},"id":"16ca9a ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# ## Creating a Geographic Plot
#
# As previously mentioned, Bokeh can also map and plot geographic data which can prove to be extremely useful. Let's first create a plot displaying CU Boulder's main campus, the SEEC building, and Pearl Street on a map of Boulder, CO.

# %%
#Set the options for the map
map_options = GMapOptions(lat=40.02, lng=-105.27, map_type="hybrid", zoom=13)

#Create the map and points that we want to plot
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
source = ColumnDataSource(
    data=dict(
        lat=[40.01, 40.01, 40.02],
        lon=[-105.27, -105.24, -105.28],
    )
)
circle = Circle(x = "lon", y = "lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="plotdiv" id="a6dffa5e-f15f-4614-891e-fbfe81df2ed8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a6dffa5e-f15f-4614-891e-fbfe81df2ed8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a6dffa5e-f15f-4614-891e-fbfe81df2ed8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"30867d7f-beda-4c1b-9dae-49ce77f793c2":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"c5af766d-4af8-41ff-9888-d6461190338a","type":"BoxAnnotation"},"plot":{"id":"5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c","type":"GMapPlot"}},"id":"33fb15f2-fc06-4f2c-9782-cd011bc7ce6f","type":"BoxSelectTool"},{"attributes":{"data_source":{"id":"5ad14d44-b180-4471-b0c8-c83502c5bfd0","type":"ColumnDataSource"},"glyph":{"id":"d5c29b4c-b902-4aae-a712-279583729ba4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c1c150db-8845-4859-9b33-fa74cd450468","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"13728df6-301c-4d00-977f-e998518f97d8","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"d5c29b4c-b902-4aae-a712-279583729ba4","type":"Circle"},{"attributes":{"map_options":{"lat":40.02,"lng":-105.27,"map_type":"hybrid","zoom":13},"renderers":[{"id":"c1c150db-8845-4859-9b33-fa74cd450468","type":"GlyphRenderer"},{"id":"c5af766d-4af8-41ff-9888-d6461190338a","type":"BoxAnnotation"}],"tool_events":{"id":"5e91962f-f110-49ba-9c1c-37d692a86c63","type":"ToolEvents"},"tools":[{"id":"f77ad4aa-4bda-455e-a6b7-40cc7fcd841c","type":"PanTool"},{"id":"1675f778-018f-4d90-adb6-0179446b5bc8","type":"WheelZoomTool"},{"id":"33fb15f2-fc06-4f2c-9782-cd011bc7ce6f","type":"BoxSelectTool"}],"x_range":{"id":"13728df6-301c-4d00-977f-e998518f97d8","type":"DataRange1d"},"y_range":{"id":"7d8dfd98-b578-4704-a189-f7f6a938b683","type":"DataRange1d"}},"id":"5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c","type":"GMapPlot"},{"attributes":{"plot":{"id":"5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c","type":"GMapPlot"}},"id":"1675f778-018f-4d90-adb6-0179446b5bc8","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"7d8dfd98-b578-4704-a189-f7f6a938b683","type":"DataRange1d"},{"attributes":{},"id":"5e91962f-f110-49ba-9c1c-37d692a86c63","type":"ToolEvents"},{"attributes":{"plot":{"id":"5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c","type":"GMapPlot"}},"id":"f77ad4aa-4bda-455e-a6b7-40cc7fcd841c","type":"PanTool"},{"attributes":{"callback":null,"column_names":["lon","lat"],"data":{"lat":[40.01,40.01,40.02],"lon":[-105.27,-105.24,-105.28]}},"id":"5ad14d44-b180-4471-b0c8-c83502c5bfd0","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c5af766d-4af8-41ff-9888-d6461190338a","type":"BoxAnnotation"}],"root_ids":["5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c"]},"title":"Bokeh Application","version":"0.11.1"}};
#             var render_items = [{"docid":"30867d7f-beda-4c1b-9dae-49ce77f793c2","elementid":"a6dffa5e-f15f-4614-891e-fbfe81df2ed8","modelid":"5ab68a6c-d4ae-40c7-93f7-a6cb79a3e55c","notebook_comms_target":"e6fda949-0810-4729-a7d3-dc0b8c507dad"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %% [markdown]
# Instead of hardcoding in lat/lon values, we can also read in a file such as a CSV containing lat/lon coordinates. Let's use the CSV in the data directory containing lat/lon coordinates of US state capitals. Additionally, we'll change the look of our map using some different options such as different colored/shaped glyphs and a different map type.

# %%
#Read in the CSV file
filename = "../data/us-state-capitals.csv"
lats = []
lons = []
with open(filename, 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='|')
    reader.__next__()
    for row in reader:
        lats.append(row[-2])
        lons.append(row[-1])

#Set the options for the map
map_options = GMapOptions(lat=37.09, lng=-95.71, map_type="satellite", zoom=3)

#Create the map
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
source = ColumnDataSource(
    data=dict(
        lat=lats,
        lon=lons,
    )
)
circle = Circle(x = "lon", y = "lat", size=8, fill_color="red", fill_alpha=0.8, line_color="blue")
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="plotdiv" id="365484a5-4376-47a6-b897-64991b9f3159"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("365484a5-4376-47a6-b897-64991b9f3159");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '365484a5-4376-47a6-b897-64991b9f3159' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2db39b6d-1c44-4f95-9959-afe8dc72e797":{"roots":{"references":[{"attributes":{"map_options":{"lat":37.09,"lng":-95.71,"zoom":3},"renderers":[{"id":"f34db0d1-c01f-4839-960e-e04f40e8b788","type":"GlyphRenderer"},{"id":"014e7793-fd0f-4cec-9a88-ed3b92fd070e","type":"BoxAnnotation"}],"tool_events":{"id":"cb72c379-6f4d-4582-a59e-f06f9042cc16","type":"ToolEvents"},"tools":[{"id":"02f38db3-26f2-43df-8112-30d44abe74f6","type":"PanTool"},{"id":"adbf1f80-0a77-433a-95f0-3eb3562333e2","type":"WheelZoomTool"},{"id":"9eab7940-eecb-4404-a8f2-cee9ca227d71","type":"BoxSelectTool"}],"x_range":{"id":"83486bb3-0a34-42ad-9bd9-b2a71a990b05","type":"DataRange1d"},"y_range":{"id":"87910d83-63e4-415a-939c-c0c9e92a8d31","type":"DataRange1d"}},"id":"5a867a81-ed58-46b3-a1f3-c4e60e6ca106","type":"GMapPlot"},{"attributes":{"plot":{"id":"5a867a81-ed58-46b3-a1f3-c4e60e6ca106","type":"GMapPlot"}},"id":"adbf1f80-0a77-433a-95f0-3eb3562333e2","type":"WheelZoomTool"},{"attributes":{"call