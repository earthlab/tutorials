# %% [markdown]
# # Introduction to Bokeh
#
# Author: Matt Oakley
#
# Another powerful visualization library available for Python is Bokeh. Much like other libraries such as Matplotlib, the aim of Bokeh is to be able to quickly and easily create interactive plots from data. This tutorial will go over the basic functionality of Bokeh.
#
# ## Objectives
#
# - Create a simple plot using Bokeh
# - Create a geospatial plot of points on a map using Bokeh
#
# ## Dependencies
#
# - Bokeh

# %%
# !pip install bokeh

# %%
from bokeh.io import output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.plotting import figure
import csv

output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f75b8d6-81ff-473b-94f4-38a03860ffa5">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Creating a Simple Plot
#
# Let's first create a simple plot of points on a Cartesian plane using Bokeh. We'll also try and change the look of our plot with Bokeh's customization features for different glyphs, markers, etc.

# %%
#Define our points to display
x_points = [1, 2, 3, 4, 5, 6, 7]
y_points = [6, 5, 4, 3, 4, 5, 6]

#Create the plot
square_plot = figure(plot_width = 400, plot_height = 400)
square_plot.square(x_points, y_points, fill_color = "red", size = 8)

#Show the plot
show(square_plot)
# Out:
#     <div class="plotdiv" id="704fadd8-4b2b-43a7-bdac-bea1bb85ab12"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("704fadd8-4b2b-43a7-bdac-bea1bb85ab12");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '704fadd8-4b2b-43a7-bdac-bea1bb85ab12' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5c77661c-f383-46cc-8348-6afc4e8a4eef":{"roots":{"references":[{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"09e804cd-8e93-4463-aeb5-74cf9fa51305","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"},"ticker":{"id":"9134755e-153b-4bb7-bf88-22f97f88c2c9","type":"BasicTicker"}},"id":"b960179e-7fbc-4daf-beba-c838da5fded8","type":"Grid"},{"attributes":{},"id":"a14e4d08-f015-4fee-acb3-e3ae98802a29","type":"ToolEvents"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"0e44ab4b-2130-49c4-8f92-d43e9cdd6b7f","type":"ResizeTool"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"31339ced-2b22-4ae0-b9a9-38b97fb33362","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"f6156f76-4752-4339-afa8-7cec88ce3e6a","type":"BasicTickFormatter"},"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5018477-baca-497a-ac50-7c90690e69a8","type":"BasicTicker"}},"id":"9a3de8e7-ac71-471a-934f-613303385fa1","type":"LinearAxis"},{"attributes":{},"id":"e5018477-baca-497a-ac50-7c90690e69a8","type":"BasicTicker"},{"attributes":{},"id":"9134755e-153b-4bb7-bf88-22f97f88c2c9","type":"BasicTicker"},{"attributes":{"callback":null},"id":"f1770cf2-62a2-4926-abe1-862c3dba09b7","type":"DataRange1d"},{"attributes":{},"id":"f6156f76-4752-4339-afa8-7cec88ce3e6a","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"024a7dca-4043-4352-9dd4-82697dbac06e","type":"Square"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"ce37db1b-b789-4a08-9698-145a7a139be2","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"6a3fc036-fc48-4055-b5fc-d6044dbc8b9e","type":"DataRange1d"},{"attributes":{"data_source":{"id":"ce37db1b-b789-4a08-9698-145a7a139be2","type":"ColumnDataSource"},"glyph":{"id":"024a7dca-4043-4352-9dd4-82697dbac06e","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"ce17063b-853b-4557-b7b9-1ba3dc85834a","type":"Square"},"selection_glyph":null},"id":"ed0bc33d-286b-432f-bdac-bb3b43f29b83","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"54bb61db-e4fa-44b4-bd00-b0b81f32725f","type":"BoxAnnotation"},"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"91a7bd22-3b32-4e7c-9859-35409b919cde","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"9a3de8e7-ac71-471a-934f-613303385fa1","type":"LinearAxis"}],"left":[{"id":"f8c28298-bea2-4298-96ad-f04a872f17b1","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"9a3de8e7-ac71-471a-934f-613303385fa1","type":"LinearAxis"},{"id":"1b143111-bd5b-41de-a811-06487e42dbd9","type":"Grid"},{"id":"f8c28298-bea2-4298-96ad-f04a872f17b1","type":"LinearAxis"},{"id":"b960179e-7fbc-4daf-beba-c838da5fded8","type":"Grid"},{"id":"54bb61db-e4fa-44b4-bd00-b0b81f32725f","type":"BoxAnnotation"},{"id":"ed0bc33d-286b-432f-bdac-bb3b43f29b83","type":"GlyphRenderer"}],"tool_events":{"id":"a14e4d08-f015-4fee-acb3-e3ae98802a29","type":"ToolEvents"},"tools":[{"id":"5a3a59ec-8f46-4e33-8969-51287f5b300c","type":"PanTool"},{"id":"31339ced-2b22-4ae0-b9a9-38b97fb33362","type":"WheelZoomTool"},{"id":"91a7bd22-3b32-4e7c-9859-35409b919cde","type":"BoxZoomTool"},{"id":"5b5f9384-c05a-4d42-992b-ed3e63120382","type":"PreviewSaveTool"},{"id":"0e44ab4b-2130-49c4-8f92-d43e9cdd6b7f","type":"ResizeTool"},{"id":"50c2593b-c3e9-46eb-9be2-e52d73c6963d","type":"ResetTool"},{"id":"09e804cd-8e93-4463-aeb5-74cf9fa51305","type":"HelpTool"}],"x_range":{"id":"6a3fc036-fc48-4055-b5fc-d6044dbc8b9e","type":"DataRange1d"},"y_range":{"id":"f1770cf2-62a2-4926-abe1-862c3dba09b7", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# As previously stated, Bokeh has a multitude of different customizations which can change the look of your plot. Let's change the squares to circles and fill them in with a different color.

# %%
#Set up a new plot using circles
circle_plot = figure(plot_width = 400, plot_height = 400)
circle_plot.circle(x_points, y_points, fill_color = "blue", size = 9)

#Display the plot
show(circle_plot)
# Out:
#     <div class="plotdiv" id="b1372f61-8631-41ba-a4c2-5b4ea07612e9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1372f61-8631-41ba-a4c2-5b4ea07612e9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1372f61-8631-41ba-a4c2-5b4ea07612e9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a9b7f247-eae9-4568-9956-705321ee0ed0":{"roots":{"references":[{"attributes":{"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"}},"id":"29fda16b-11d6-489e-bf7d-e7024da89b37","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"09e804cd-8e93-4463-aeb5-74cf9fa51305","type":"HelpTool"},{"attributes":{"overlay":{"id":"54bb61db-e4fa-44b4-bd00-b0b81f32725f","type":"BoxAnnotation"},"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"91a7bd22-3b32-4e7c-9859-35409b919cde","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aae2670-5c7c-4084-8801-f3b5b2894240","type":"BasicTicker"}},"id":"31c0b229-a073-468d-83db-ea6844819985","type":"Grid"},{"attributes":{"callback":null},"id":"f5aa63fb-bd49-4112-ac8d-9da9d7fba4ab","type":"DataRange1d"},{"attributes":{"below":[{"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"}],"left":[{"id":"dbf5e197-ac0d-4796-8b9d-2b47732d92ee","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"},{"id":"31c0b229-a073-468d-83db-ea6844819985","type":"Grid"},{"id":"dbf5e197-ac0d-4796-8b9d-2b47732d92ee","type":"LinearAxis"},{"id":"7a07d9ae-bc99-49a0-b64a-213d9d6ab13c","type":"Grid"},{"id":"b065505d-9cce-4ee5-aa9b-b9ad64c5f1f8","type":"BoxAnnotation"},{"id":"aa1e71d7-ec03-4422-b342-752cce730d28","type":"GlyphRenderer"}],"tool_events":{"id":"ed7b2fc2-2160-46ab-9557-34f320953040","type":"ToolEvents"},"tools":[{"id":"b4873b69-3c6a-4d47-8c58-b43dabd204ed","type":"PanTool"},{"id":"29fda16b-11d6-489e-bf7d-e7024da89b37","type":"WheelZoomTool"},{"id":"56b4da22-6455-43c5-b039-34f496e922cd","type":"BoxZoomTool"},{"id":"22127e7a-aa66-48a4-a5ce-6bf15ece6252","type":"PreviewSaveTool"},{"id":"435231d6-8be7-4208-9d3d-4ce8c73dbd89","type":"ResizeTool"},{"id":"8185c04d-5b92-41b0-80fb-adc8cba873b9","type":"ResetTool"},{"id":"feba0f95-8989-4c97-a0c8-9719c5ea70c0","type":"HelpTool"}],"x_range":{"id":"04955dc9-165c-4b95-96ad-0a4eb825ea4b","type":"DataRange1d"},"y_range":{"id":"f5aa63fb-bd49-4112-ac8d-9da9d7fba4ab","type":"DataRange1d"}},"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"048b5447-9799-4551-8c6c-679ea6fca94f","type":"BasicTickFormatter"},"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aae2670-5c7c-4084-8801-f3b5b2894240","type":"BasicTicker"}},"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"cc7379fd-5c86-4cb5-9e89-cd739acf0fa5","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b065505d-9cce-4ee5-aa9b-b9ad64c5f1f8","type":"BoxAnnotation"},"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"}},"id":"56b4da22-6455-43c5-b039-34f496e922cd","type":"BoxZoomTool"},{"attributes":{},"id":"048b5447-9799-4551-8c6c-679ea6fca94f","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"024a7dca-4043-4352-9dd4-82697dbac06e","type":"Square"},{"attributes":{},"id":"a14e4d08-f015-4fee-acb3-e3ae98802a29","type":"ToolEvents"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"0e44ab4b-2130-49c4-8f92-d43e9cdd6b7f","type":"ResizeTool"},{"attributes":{"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"}},"id":"feba0f95-8989-4c97-a0c8-9719c5ea70c0","type":"HelpTool"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"31339ced-2b22-4ae0-b9a ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# Finally, let's display a line on our plot connecting all of our plotted points.

# %%
#Create a line connecting our plotted points
circle_plot.line(x_points, y_points, line_width = 2)

#Display the plot
show(circle_plot)
# Out:
#     <div class="plotdiv" id="f130043c-7655-4b26-ba45-4e1f5fe0a220"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f130043c-7655-4b26-ba45-4e1f5fe0a220");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f130043c-7655-4b26-ba45-4e1f5fe0a220' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f97024d7-0d49-4268-9b2f-e0eefed3274c":{"roots":{"references":[{"attributes":{"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"}},"id":"29fda16b-11d6-489e-bf7d-e7024da89b37","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"09e804cd-8e93-4463-aeb5-74cf9fa51305","type":"HelpTool"},{"attributes":{"overlay":{"id":"54bb61db-e4fa-44b4-bd00-b0b81f32725f","type":"BoxAnnotation"},"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"91a7bd22-3b32-4e7c-9859-35409b919cde","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aae2670-5c7c-4084-8801-f3b5b2894240","type":"BasicTicker"}},"id":"31c0b229-a073-468d-83db-ea6844819985","type":"Grid"},{"attributes":{"callback":null},"id":"f5aa63fb-bd49-4112-ac8d-9da9d7fba4ab","type":"DataRange1d"},{"attributes":{"below":[{"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"}],"left":[{"id":"dbf5e197-ac0d-4796-8b9d-2b47732d92ee","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"},{"id":"31c0b229-a073-468d-83db-ea6844819985","type":"Grid"},{"id":"dbf5e197-ac0d-4796-8b9d-2b47732d92ee","type":"LinearAxis"},{"id":"7a07d9ae-bc99-49a0-b64a-213d9d6ab13c","type":"Grid"},{"id":"b065505d-9cce-4ee5-aa9b-b9ad64c5f1f8","type":"BoxAnnotation"},{"id":"aa1e71d7-ec03-4422-b342-752cce730d28","type":"GlyphRenderer"},{"id":"ec48ceea-c5b8-45d9-94b8-83c16c09d46b","type":"GlyphRenderer"}],"tool_events":{"id":"ed7b2fc2-2160-46ab-9557-34f320953040","type":"ToolEvents"},"tools":[{"id":"b4873b69-3c6a-4d47-8c58-b43dabd204ed","type":"PanTool"},{"id":"29fda16b-11d6-489e-bf7d-e7024da89b37","type":"WheelZoomTool"},{"id":"56b4da22-6455-43c5-b039-34f496e922cd","type":"BoxZoomTool"},{"id":"22127e7a-aa66-48a4-a5ce-6bf15ece6252","type":"PreviewSaveTool"},{"id":"435231d6-8be7-4208-9d3d-4ce8c73dbd89","type":"ResizeTool"},{"id":"8185c04d-5b92-41b0-80fb-adc8cba873b9","type":"ResetTool"},{"id":"feba0f95-8989-4c97-a0c8-9719c5ea70c0","type":"HelpTool"}],"x_range":{"id":"04955dc9-165c-4b95-96ad-0a4eb825ea4b","type":"DataRange1d"},"y_range":{"id":"f5aa63fb-bd49-4112-ac8d-9da9d7fba4ab","type":"DataRange1d"}},"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"048b5447-9799-4551-8c6c-679ea6fca94f","type":"BasicTickFormatter"},"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aae2670-5c7c-4084-8801-f3b5b2894240","type":"BasicTicker"}},"id":"a2d93c10-dfb7-44c1-b095-a2137f065d52","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"cc7379fd-5c86-4cb5-9e89-cd739acf0fa5","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b065505d-9cce-4ee5-aa9b-b9ad64c5f1f8","type":"BoxAnnotation"},"plot":{"id":"37cec6cd-384a-4cf0-8d08-bd58622b965d","subtype":"Figure","type":"Plot"}},"id":"56b4da22-6455-43c5-b039-34f496e922cd","type":"BoxZoomTool"},{"attributes":{},"id":"048b5447-9799-4551-8c6c-679ea6fca94f","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2961a612-f046-4b33-914a-2f17069e17a7","type":"Line"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"024a7dca-4043-4352-9dd4-82697dbac06e","type":"Square"},{"attributes":{},"id":"a14e4d08-f015-4fee-acb3-e3ae98802a29","type":"ToolEvents"},{"attributes":{"plot":{"id":"a74b0f76-54f6-4cb3-a3ad-bdc3669add6d","subtype":"Figure","type":"Plot"}},"id":"0e44ab4b-2130-49c4-8f92-d43e9cdd6b7f","type":"ResizeTool"},{"attributes":{"plot":{"id":"3 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# ## Creating a Geographic Plot
#
# As previously mentioned, Bokeh can also map and plot geographic data which can prove to be extremely useful. Let's first create a plot displaying CU Boulder's main campus, the SEEC building, and Pearl Street on a map of Boulder, CO.

# %%
#Set the options for the map
map_options = GMapOptions(lat=40.02, lng=-105.27, map_type="hybrid", zoom=13)

#Create the map and points that we want to plot
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
source = ColumnDataSource(
    data=dict(
        lat=[40.01, 40.01, 40.02],
        lon=[-105.27, -105.24, -105.28],
    )
)
circle = Circle(x = "lon", y = "lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="plotdiv" id="90e451f8-1f55-4e14-955f-0d48e27d63ca"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("90e451f8-1f55-4e14-955f-0d48e27d63ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '90e451f8-1f55-4e14-955f-0d48e27d63ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"416614aa-7d05-4126-8b0a-a9ad1aad4c5e":{"roots":{"references":[{"attributes":{"map_options":{"lat":40.02,"lng":-105.27,"map_type":"hybrid","zoom":13},"renderers":[{"id":"704242ff-c94a-42c6-8479-be4fb73f1cf6","type":"GlyphRenderer"},{"id":"4a50d721-5df3-4fa5-a08b-00d49b229c31","type":"BoxAnnotation"}],"tool_events":{"id":"366d3737-8872-4c1a-80de-36a838632fe7","type":"ToolEvents"},"tools":[{"id":"0b6fa565-66d6-4f97-bc29-85999874ebee","type":"PanTool"},{"id":"9d4830cc-9dd1-4d91-8e2b-3a981a65c2c0","type":"WheelZoomTool"},{"id":"20b89d8e-09a4-4c26-a19d-a73b7b044eb6","type":"BoxSelectTool"}],"x_range":{"id":"f1dea22a-183f-4aa7-bb34-a18decb0af54","type":"DataRange1d"},"y_range":{"id":"88408dcf-457c-4723-aec2-21b8828f3350","type":"DataRange1d"}},"id":"18615826-e5aa-4e07-abee-e0c33ffaf9c9","type":"GMapPlot"},{"attributes":{"callback":null},"id":"88408dcf-457c-4723-aec2-21b8828f3350","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4a50d721-5df3-4fa5-a08b-00d49b229c31","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"18615826-e5aa-4e07-abee-e0c33ffaf9c9","type":"GMapPlot"}},"id":"9d4830cc-9dd1-4d91-8e2b-3a981a65c2c0","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"f1dea22a-183f-4aa7-bb34-a18decb0af54","type":"DataRange1d"},{"attributes":{"data_source":{"id":"6b0f830f-a978-4f66-9424-287963c7eae1","type":"ColumnDataSource"},"glyph":{"id":"9b1dde49-5c1f-447f-8cab-50f418d6bfde","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"704242ff-c94a-42c6-8479-be4fb73f1cf6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"9b1dde49-5c1f-447f-8cab-50f418d6bfde","type":"Circle"},{"attributes":{"callback":null,"overlay":{"id":"4a50d721-5df3-4fa5-a08b-00d49b229c31","type":"BoxAnnotation"},"plot":{"id":"18615826-e5aa-4e07-abee-e0c33ffaf9c9","type":"GMapPlot"}},"id":"20b89d8e-09a4-4c26-a19d-a73b7b044eb6","type":"BoxSelectTool"},{"attributes":{},"id":"366d3737-8872-4c1a-80de-36a838632fe7","type":"ToolEvents"},{"attributes":{"plot":{"id":"18615826-e5aa-4e07-abee-e0c33ffaf9c9","type":"GMapPlot"}},"id":"0b6fa565-66d6-4f97-bc29-85999874ebee","type":"PanTool"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.01,40.01,40.02],"lon":[-105.27,-105.24,-105.28]}},"id":"6b0f830f-a978-4f66-9424-287963c7eae1","type":"ColumnDataSource"}],"root_ids":["18615826-e5aa-4e07-abee-e0c33ffaf9c9"]},"title":"Bokeh Application","version":"0.11.1"}};
#             var render_items = [{"docid":"416614aa-7d05-4126-8b0a-a9ad1aad4c5e","elementid":"90e451f8-1f55-4e14-955f-0d48e27d63ca","modelid":"18615826-e5aa-4e07-abee-e0c33ffaf9c9","notebook_comms_target":"59d0035c-1119-4042-9e5b-4fe122858731"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %% [markdown]
# Instead of hardcoding in lat/lon values, we can also read in a file such as a CSV containing lat/lon coordinates. Let's use the CSV in the data directory containing lat/lon coordinates of US state capitals. Additionally, we'll change the look of our map using some different options such as different colored/shaped glyphs and a different map type.

# %%
#Read in the CSV file
filename = "../data/us-state-capitals.csv"
lats = []
lons = []
with open(filename, 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='|')
    reader.next()
    for row in reader:
        lats.append(row[-2])
        lons.append(row[-1])

#Set the options for the map
map_options = GMapOptions(lat=37.09, lng=-95.71, map_type="satellite", zoom=3)

#Create the map
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
source = ColumnDataSource(
    data=dict(
        lat=lats,
        lon=lons,
    )
)
circle = Circle(x = "lon", y = "lat", size=8, fill_color="red", fill_alpha=0.8, line_color="blue")
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="plotdiv" id="51462c74-d257-4ccc-89ef-b046f03f0f5b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51462c74-d257-4ccc-89ef-b046f03f0f5b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51462c74-d257-4ccc-89ef-b046f03f0f5b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e4ec3c6f-cd43-4160-8050-856b9e4f9d0f":{"roots":{"references":[{"attributes":{"plot":{"id":"abf7ed02-09b9-4b0f-8ed3-9bf6476d164d","type":"GMapPlot"}},"id":"31c583d1-a80c-4c33-b0a1-7e73c9c72235","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"2f0d0999-0c5e-4f38-ab75-a98f33798a43","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a56e9e25-76be-4191-9a6b-3e41332fe9dc","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":["32.377716","58.301598","33.448143","34.746613","38.576668","39.739227","41.764046","39.157307","21.307442","30.438118","33.749027","43.617775","39.798363","39.768623","41.591087","39.048191","38.186722","30.457069","44.307167","38.978764","42.358162","42.733635","44.955097","32.303848","38.579201","46.585709","40.808075","39.163914","43.206898","40.220596","35.68224","35.78043","46.82085","42.652843","39.961346","35.492207","44.938461","40.264378","41.830914","34.000343","44.367031","36.16581","30.27467","40.777477","44.262436","37.538857","47.035805","38.336246","43.074684","41.140259"],"lon":["-86.300568","-134.420212","-112.096962","-92.288986","-121.493629","-104.984856","-72.682198","-75.519722","-157.857376","-84.281296","-84.388229","-116.199722","-89.654961","-86.162643","-93.603729","-95.677956","-84.875374","-91.187393","-69.781693","-76.490936","-71.063698","-84.555328","-93.102211","-90.182106","-92.172935","-112.018417","-96.699654","-119.766121","-71.537994","-74.769913","-105.939728","-78.639099","-100.783318","-73.757874","-82.999069","-97.503342","-123.030403","-76.883598","-71.414963","-81.033211","-100.346405","-86.784241","-97.740349","-111.888237","-72.580536","-77.43364","-122.905014","-81.612328","-89.384445","-104.820236"]}},"id":"28aa2626-e942-4461-8c84-817bd561834e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"28aa2626-e942-4461-8c84-817bd561834e","type":"ColumnDataSource"},"glyph":{"id":"ffe24cb5-0a05-4127-8b5a-479924d73139","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0164c9a4-f0cb-4be4-8560-fe039e87f4be","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"abf7ed02-09b9-4b0f-8ed3-9bf6476d164d","type":"GMapPlot"}},"id":"9236e0f6-9d61-4cf2-9131-1e172481011c","type":"PanTool"},{"attributes":{"map_options":{"lat":37.09,"lng":-95.71,"zoom":3},"renderers":[{"id":"0164c9a4-f0cb-4be4-8560-fe039e87f4be","type":"GlyphRenderer"},{"id":"a56e9e25-76be-4191-9a6b-3e41332fe9dc","type":"BoxAnnotation"}],"tool_events":{"id":"2bdd4348-b336-4e95-8789-2de1fffb0c2e","type":"ToolEvents"},"tools":[{"id":"9236e0f6-9d61-4cf2-9131-1e172481011c","type":"PanTool"},{"id":"31c583d1-a80c-4c33-b0a1-7e73c9c72235","type":"WheelZoomTool"},{"id":"720a5f5e-978f-40d3-a720-1af255f035e0","type":"BoxSelectTool"}],"x_range":{"id":"2f0d0999-0c5e-4f38-ab75-a98f33798a43","type":"DataRange1d"},"y_range":{"id":"1c805958-3bdd-49bf-b082-cca41b546166","type":"DataRange1d"}},"id":"abf7ed02-09b9-4b0f-8ed3-9bf6476d164d","type":"GMapPlot"},{"attributes":{},"id":"2bdd4348-b336-4e95-8789-2de1fffb0c2e","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"red"},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"ffe24cb5-0a05-4127-8b5a-479924d73139","type":"Circle"},{"attributes":{"callback":null},"id":"1c805958-3bdd-49bf-b082-cca41b546166","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"a56e9e25-76be-4191-9a6b-3e41332fe9dc","type":"BoxAnnotation"},"plot":{"id":"abf7ed02-09b9-4b0f-8ed3-9bf6476d164d","type":"GMapPlot"}},"id":"720a5f5e-978f-40d3-a720-1af255f035e0","type":"BoxSelectTool"}] ...
#             var render_items = [{"docid":"e4ec3c6f-cd43-4160-8050-856b9e4f9d0f","elementid":"51462c74-d257-4ccc-89ef-b046f03f0f5b","modelid":"abf7ed02-09b9-4b0f-8ed3-9bf6476d164d","notebook_comms_target":"72dc494a-170d-415c-8e95-2ae7ef0cd42c"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>
