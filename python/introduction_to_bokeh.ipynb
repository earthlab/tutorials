# %% [markdown]
# # Introduction to Bokeh in Python
#
# Author: Matt Oakley
#
# Another powerful visualization library available for Python is Bokeh. Much like other libraries such as Matplotlib, the aim of Bokeh is to be able to quickly and easily create interactive plots from data. This tutorial will go over the basic functionality of Bokeh.
#
# Note: this tutorial produces interactive plots. If not running locally, we recommend using [nbviewer](http://nbviewer.jupyter.org/github/earthlab/tutorials/blob/master/python/introduction_to_bokeh.ipynb) to view the tutorial.
#
# ## Objectives
#
# - Create a simple plot using Bokeh
# - Create a geospatial plot of points on a map using Bokeh
#
# ## Dependencies
#
# - Bokeh

# %%
from bokeh.io import output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.plotting import figure
import csv

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33bce66c-b6c1-441e-bb42-77c90f5b76ac">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Creating a Simple Plot
#
# Let's first create a simple plot of points on a Cartesian plane using Bokeh. We'll also try and change the look of our plot with Bokeh's customization features for different glyphs, markers, etc.

# %%
#Define our points to display
x_points = [1, 2, 3, 4, 5, 6, 7]
y_points = [6, 5, 4, 3, 4, 5, 6]

#Create the plot
square_plot = figure(plot_width = 400, plot_height = 400)
square_plot.square(x_points, y_points, fill_color = "red", size = 8)

#Show the plot
show(square_plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="07c469cb-ea9d-4c41-9ba8-7b821ead8cde"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07c469cb-ea9d-4c41-9ba8-7b821ead8cde");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07c469cb-ea9d-4c41-9ba8-7b821ead8cde' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3aa58e74-0585-4fd4-a3f0-903da7d6a6f5":{"roots":{"references":[{"attributes":{"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"}},"id":"076f24f1-c09a-4058-b4fd-09154c435008","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"1ac802ab-0074-415b-87de-74d3477df1e9","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"4b00d442-6219-4745-8374-070ca2b68622","type":"BoxAnnotation"},"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"}},"id":"debbf3bc-88b2-4588-9754-02956f7693d6","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"4b94d076-726f-4f0a-b3f1-7270ca9dd340","type":"DataRange1d"},{"attributes":{},"id":"0406b85c-cda1-4831-b591-4d5eaceb67ce","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"}},"id":"8126eb19-974f-41e0-b77c-5b057aeef401","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"0406b85c-cda1-4831-b591-4d5eaceb67ce","type":"BasicTickFormatter"},"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e861a1b-e743-4182-864c-361f9ee11527","type":"BasicTicker"}},"id":"495e1798-b279-49a2-9231-afa805c3d28d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"1ac802ab-0074-415b-87de-74d3477df1e9","type":"ColumnDataSource"},"glyph":{"id":"df2de0e7-fa19-42be-bda0-4a6d54bff4e2","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"c1c4bab0-7cfb-4b54-94a9-456985d32348","type":"Square"},"selection_glyph":null},"id":"86c6cd41-7021-49b5-b107-3bfe9cea1d71","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"}},"id":"3453fe56-15b3-484d-9835-7d162cab9456","type":"ResetTool"},{"attributes":{"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"}},"id":"365345b7-813a-44ca-8a99-94a57e3bef03","type":"HelpTool"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"df2de0e7-fa19-42be-bda0-4a6d54bff4e2","type":"Square"},{"attributes":{"dimension":1,"plot":{"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"},"ticker":{"id":"3e861a1b-e743-4182-864c-361f9ee11527","type":"BasicTicker"}},"id":"3c7a1c77-c1c9-4ca7-8563-ac5203a0120b","type":"Grid"},{"attributes":{},"id":"3e861a1b-e743-4182-864c-361f9ee11527","type":"BasicTicker"},{"attributes":{"below":[{"id":"46521d4c-927d-45f2-a2e3-fff01da6bca5","type":"LinearAxis"}],"left":[{"id":"495e1798-b279-49a2-9231-afa805c3d28d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"46521d4c-927d-45f2-a2e3-fff01da6bca5","type":"LinearAxis"},{"id":"bad13d06-7e6b-46ca-a89e-0232400e855f","type":"Grid"},{"id":"495e1798-b279-49a2-9231-afa805c3d28d","type":"LinearAxis"},{"id":"3c7a1c77-c1c9-4ca7-8563-ac5203a0120b","type":"Grid"},{"id":"4b00d442-6219-4745-8374-070ca2b68622","type":"BoxAnnotation"},{"id":"86c6cd41-7021-49b5-b107-3bfe9cea1d71","type":"GlyphRenderer"}],"title":{"id":"452baa74-a6e2-4b00-b5e5-3a067203a30d","type":"Title"},"tool_events":{"id":"98f2fdd2-153f-49e4-a096-67986ededddc","type":"ToolEvents"},"toolbar":{"id":"8dece2e3-2479-4b09-bfa8-8bd31103ad69","type":"Toolbar"},"x_range":{"id":"4b94d076-726f-4f0a-b3f1-7270ca9dd340","type":"DataRange1d"},"y_range":{"id":"6f686c17-377e-4d9b-9d33-37f522ceb73b","type":"DataRange1d"}},"id":"4914fc3a-bab0-4d32-a65d-7a2671a85180","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":null},"id":"452baa74-a6e2-4b00-b5e5-3a067203a30d","type":"Title"},{"attributes":{},"id":"a7c38279-f234-432d-b5fd-8eb17683a55a","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# As previously stated, Bokeh has a multitude of different customizations which can change the look of your plot. Let's change the squares to circles and fill them in with a different color.

# %%
#Set up a new plot using circles
circle_plot = figure(plot_width = 400, plot_height = 400)
circle_plot.circle(x_points, y_points, fill_color = "blue", size = 9)

#Display the plot
show(circle_plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="534e41ac-92e9-49b1-9983-182cf11f01d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("534e41ac-92e9-49b1-9983-182cf11f01d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '534e41ac-92e9-49b1-9983-182cf11f01d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"
type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0fdd701d-5849-4321-a205-a2204053784e","type":"PanTool"},{"id":"44a490d6-ca64-44b0-8913-e333f12a2c07","type":"WheelZoomTool"},{"id":"1b59c29b-cea4-491e-abba-e003cf75c595","type":"BoxZoomTool"},{"id":"883480a0-ea03-461c-a8e1-46d302c7dec9","type":"SaveTool"},{"id":"0cca6c11-3d37-43c5-9d39-49d9ed9f0009","type":"ResetTool"},{"id":"fd2abe9e-94fd-49ca-bb2b-88d12060b4ea","type":"HelpTool"}]},"id":"41f818fb-2db5-4e3d-84c8-efe7b8572624","type":"Toolbar"},{"attributes":{},"id":"56e9a7a6-5b20-4835-a8b5-7e7f734b0ecb","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7],"y":[6,5,4,3,4,5,6]}},"id":"0941e3d4-b747-49e2-979d-615c5fc331ec","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":9},"x":{"fiel ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# Finally, let's display a line on our plot connecting all of our plotted points.

# %%
#Create a line connecting our plotted points
circle_plot.line(x_points, y_points, line_width = 2)

#Display the plot
show(circle_plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a9238c5a-afaa-48d3-90e5-0bc67d5f033b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a9238c5a-afaa-48d3-90e5-0bc67d5f033b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a9238c5a-afaa-48d3-90e5-0bc67d5f033b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"342a6048-8442-4e61-ab93-ba1728e5d537":{"roots":{"references":[{"attributes":{"formatter":{"id":"b1f18974-62e1-468a-a669-8b8cc6401c1b","type":"BasicTickFormatter"},"plot":{"id":"ca1c9537-97aa-4c1c-b3bf-b6da4b85ce6b","subtype":"Figure","type":"Plot"},"ticker":{"id":"56e9a7a6-5b20-4835-a8b5-7e7f734b0ecb","type":"BasicTicker"}},"id":"71cff24c-eb88-4840-8272-ba7dea31af8c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"5fcb39fb-2a76-4106-b67a-001a121c1c09","type":"ColumnDataSource"},"glyph":{"id":"b586d8a3-e515-4406-aeae-1c3181513a52","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dd6819fc-8f87-4edc-94d2-3c1d0b07f80a","type":"Line"},"selection_glyph":null},"id":"90b6c76c-fd36-4e68-904c-46f075f3f297","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"71cff24c-eb88-4840-8272-ba7dea31af8c","type":"LinearAxis"}],"left":[{"id":"1f97fb9a-d357-483e-8e0e-f985ff10e999","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"71cff24c-eb88-4840-8272-ba7dea31af8c","type":"LinearAxis"},{"id":"6d7177fb-3172-42b2-87e6-1445ba61f09a","type":"Grid"},{"id":"1f97fb9a-d357-483e-8e0e-f985ff10e999","type":"LinearAxis"},{"id":"33aac4f8-fa63-4f81-ad46-f7ba668474bb","type":"Grid"},{"id":"e3cbaa88-1f8c-4af7-98e8-dcf583e21629","type":"BoxAnnotation"},{"id":"8b1b0be4-4a48-4a99-a518-d5671186f091","type":"GlyphRenderer"},{"id":"90b6c76c-fd36-4e68-904c-46f075f3f297","type":"GlyphRenderer"}],"title":{"id":"593301b9-4656-4a7e-8d5f-206be9af3452","type":"Title"},"tool_events":{"id":"d502c1d1-671d-455c-993f-bd7f115b70d9","type":"ToolEvents"},"toolbar":{"id":"41f818fb-2db5-4e3d-84c8-efe7b8572624","type":"Toolbar"},"x_range":{"id":"3086ce06-c11f-4c53-abdf-5a14f437431e","type":"DataRange1d"},"y_range":{"id":"314bd303-f535-4fd7-8b5c-b56c2d20a305","type":"DataRange1d"}},"id":"ca1c9537-97aa-4c1c-b3bf-b6da4b85ce6b","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c06d7c90-6007-4eee-b18a-a19a97faf46e","type":"BasicTickFormatter"},{"attributes":{},"id":"89cfaa60-0e52-40f1-9a0a-eca6f01811bc","type":"BasicTicker"},{"attributes":{},"id":"b1f18974-62e1-468a-a669-8b8cc6401c1b","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"e3cbaa88-1f8c-4af7-98e8-dcf583e21629","type":"BoxAnnotation"},"plot":{"id":"ca1c9537-97aa-4c1c-b3bf-b6da4b85ce6b","subtype":"Figure","type":"Plot"}},"id":"1b59c29b-cea4-491e-abba-e003cf75c595","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"314bd303-f535-4fd7-8b5c-b56c2d20a305","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e3cbaa88-1f8c-4af7-98e8-dcf583e21629","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd6819fc-8f87-4edc-94d2-3c1d0b07f80a","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b586d8a3-e515-4406-aeae-1c3181513a52","type":"Line"},{"attributes":{"plot":{"id":"ca1c9537-97aa-4c1c-b3bf-b6da4b85ce6b","subtype":"Figure","type":"Plot"}},"id":"44a490d6-ca64-44b0-8913-e333f12a2c07","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"ca1c9537-97aa-4c1c-b3bf-b6da4b85ce6b","subtype":"Figure","type":"Plot"}},"id":"fd2abe9e-94fd-49ca-bb2b-88d12060b4ea","type":"HelpTool"},{"attributes":{},"id":"d502c1d1-671d-455c-993f-bd7f115b70d9","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0fdd701d-5849-4321-a205-a2204053784e","type":"PanTool"},{"id":"44a490d6-ca64-44b0-8913-e333f12a2c07","type":"WheelZoomTool"},{"id":"1b59c29b-cea4-491e-abba-e003cf75c595","type":"BoxZoomTool"},{"id":"883480a0-ea03-461c ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# ## Creating a Geographic Plot
#
# As previously mentioned, Bokeh can also map and plot geographic data which can prove to be extremely useful. Let's first create a plot displaying CU Boulder's main campus, the SEEC building, and Pearl Street on a map of Boulder, CO. To use the google map features, you will need to aquire an api key. To do this, go [here](https://developers.google.com/maps/documentation/javascript/get-api-key) and click GET A KEY. Now copy the provided key, and set the `API_KEY` variable

# %%
#Set api key
API_KEY = 'AIzaSyCZ4o3KU5M-r_79EBkH9PRCV2KZerjZKcM'
#Set the options for the map
map_options = GMapOptions(lat=40.02, lng=-105.27, map_type="hybrid", zoom=13)

#Create the map and points that we want to plot
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, api_key = API_KEY)
source = ColumnDataSource(
    data=dict(
        lat=[40.01, 40.01, 40.02],
        lon=[-105.27, -105.24, -105.28],
    )
)
circle = Circle(x = "lon", y = "lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ffc32d72-bfc5-456a-b4b0-da30475d82d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ffc32d72-bfc5-456a-b4b0-da30475d82d4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ffc32d72-bfc5-456a-b4b0-da30475d82d4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a799fbf6-fd16-4076-936d-8e35079884b0":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"55f6bc60-053f-4379-a864-b5fc640eb9de","type":"BoxAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"55f6bc60-053f-4379-a864-b5fc640eb9de","type":"BoxAnnotation"},"plot":{"id":"67a16e5d-f344-4821-a084-57a56635f31c","type":"GMapPlot"}},"id":"fbb27272-cb01-477a-8522-7f5476b3527a","type":"BoxSelectTool"},{"attributes":{"callback":null},"id":"8d719959-1cd7-4bf8-9521-7886991b5d54","type":"DataRange1d"},{"attributes":{"callback":null},"id":"9386ced0-8b4e-4cb1-bba8-0ea5d04866d2","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"3493c073-17fb-473b-b568-477d5de24119","type":"Circle"},{"attributes":{"api_key":"AIzaSyCZ4o3KU5M-r_79EBkH9PRCV2KZerjZKcM","map_options":{"lat":40.02,"lng":-105.27,"map_type":"hybrid","zoom":13},"renderers":[{"id":"33fab10f-334f-4667-9f5a-b7af59168938","type":"GlyphRenderer"},{"id":"55f6bc60-053f-4379-a864-b5fc640eb9de","type":"BoxAnnotation"}],"title":{"id":"0711a4fa-98bc-43b8-a4eb-eaad0a8f729f","type":"Title"},"tool_events":{"id":"6ade2809-3d0a-4860-a329-410655436a38","type":"ToolEvents"},"toolbar":{"id":"7e95e357-ee3a-4e0f-abcf-b7c679267b35","type":"Toolbar"},"x_range":{"id":"8d719959-1cd7-4bf8-9521-7886991b5d54","type":"DataRange1d"},"y_range":{"id":"9386ced0-8b4e-4cb1-bba8-0ea5d04866d2","type":"DataRange1d"}},"id":"67a16e5d-f344-4821-a084-57a56635f31c","type":"GMapPlot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ff7ebb16-8a3e-480e-9bcd-b04c109cdb93","type":"PanTool"},{"id":"5b00ca82-40b9-4273-83fd-3302e8b12d43","type":"WheelZoomTool"},{"id":"fbb27272-cb01-477a-8522-7f5476b3527a","type":"BoxSelectTool"}]},"id":"7e95e357-ee3a-4e0f-abcf-b7c679267b35","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"0711a4fa-98bc-43b8-a4eb-eaad0a8f729f","type":"Title"},{"attributes":{"plot":{"id":"67a16e5d-f344-4821-a084-57a56635f31c","type":"GMapPlot"}},"id":"5b00ca82-40b9-4273-83fd-3302e8b12d43","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"67a16e5d-f344-4821-a084-57a56635f31c","type":"GMapPlot"}},"id":"ff7ebb16-8a3e-480e-9bcd-b04c109cdb93","type":"PanTool"},{"attributes":{},"id":"6ade2809-3d0a-4860-a329-410655436a38","type":"ToolEvents"},{"attributes":{"data_source":{"id":"03c1a9d1-59dd-4bfe-9d88-8d771dbb55e8","type":"ColumnDataSource"},"glyph":{"id":"3493c073-17fb-473b-b568-477d5de24119","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"33fab10f-334f-4667-9f5a-b7af59168938","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["lon","lat"],"data":{"lat":[40.01,40.01,40.02],"lon":[-105.27,-105.24,-105.28]}},"id":"03c1a9d1-59dd-4bfe-9d88-8d771dbb55e8","type":"ColumnDataSource"}],"root_ids":["67a16e5d-f344-4821-a084-57a56635f31c"]},"title":"Bokeh Application","version":"0.12.1"}};
#             var render_items = [{"docid":"a799fbf6-fd16-4076-936d-8e35079884b0","elementid":"ffc32d72-bfc5-456a-b4b0-da30475d82d4","modelid":"67a16e5d-f344-4821-a084-57a56635f31c","notebook_comms_target":"9d892e6a-fecf-4e16-97bb-7afdc8180fef"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %% [markdown]
# Instead of hardcoding in lat/lon values, we can also read in a file such as a CSV containing lat/lon coordinates. Let's use the CSV in the data directory containing lat/lon coordinates of US state capitals. Additionally, we'll change the look of our map using some different options such as different colored/shaped glyphs and a different map type.

# %%
#Read in the CSV file
filename = "../data/us-state-capitals.csv"
lats = []
lons = []
with open(filename, 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='|')
    reader.__next__()
    for row in reader:
        lats.append(row[-2])
        lons.append(row[-1])

#Set the options for the map
map_options = GMapOptions(lat=37.09, lng=-95.71, map_type="satellite", zoom=3)

#Create the map
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, api_key=API_KEY)
source = ColumnDataSource(
    data=dict(
        lat=lats,
        lon=lons,
    )
)
circle = Circle(x = "lon", y = "lat", size=8, fill_color="red", fill_alpha=0.8, line_color="blue")
plot.add_glyph(source, circle)
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

#Display the plot
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f6fb8974-9d5a-4a39-a04e-178e2f799b53"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6fb8974-9d5a-4a39-a04e-178e2f799b53");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6fb8974-9d5a-4a39-a04e-178e2f799b53' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ab240975-39f4-44c9-9f1e-07f45f72b026":{"roots":{"references":[{"attributes":{"api_key":"AIzaSyCZ4o3KU5M-r_79EBkH9PRCV2KZerjZKcM","map_options":{"lat":37.09,"lng":-95.71,"zoom":3},"renderers":[{"id":"f9a3a4ff-3f0e-47ee-b65c-47bc7b540670","type":"GlyphRenderer"},{"id":"30db4d19-1d04-4f86-9963-25166ca6cfea","type":"BoxAnnotation"}],"title":{"id":"094c58af-b284-4ccf-bc16-a75ed21e9868","type":"Title"},"tool_events":{"id":"b0471374-191b-4d84-abd2-788b807bddc3","type":"ToolEvents"},"toolbar":{"id":"4dffb8bd-c70d-48bf-b736-c96093522bc1","type":"Toolbar"},"x_range":{"id":"8d9915e0-f740-44ee-b268-dbfaa1401bd2","type":"DataRange1d"},"y_range":{"id":"aeaa2ab7-a65f-42a4-90b3-69f54ea8f62f","type":"DataRange1d"}},"id":"65b4cc67-5404-4604-96d1-f7697513c784","type":"GMapPlot"},{"attributes":{"data_source":{"id":"78615ab0-cd54-44bc-a894-3c293893e159","type":"ColumnDataSource"},"glyph":{"id":"ec9dde47-0d40-482a-b2fc-c25e37df4147","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"